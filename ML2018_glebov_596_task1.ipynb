# %% [markdown]
# <span style="font-size: 14pt">Домашнее задание №1 </span>
#
# <span style="color: red; font-size: 14pt">Deadline: 27.02.2018 23:59:59</span>
#
# <span style="font-size: 10pt">ФИВТ, АПТ, Курс по машинному обучению, Весна 2018</span>
#
# <span style="color:blue; font-size: 10pt">Alexey Romanenko, </span>
# <span style="color:blue; font-size: 10pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Воронцов К. В. Математические методы обучения по прецедентам. 2012.
# - Мерков А. Б. Распознавание образов. Введение в методы статистического обучения. Едиториал УРСС. 2011. 256 стр.
# - Hastie T., Tibshirani R., Friedman J. The Elements of Statistical Learning. Springer: Data Mining, Inference, and Prediction. — 2nd ed. — Springer-Verlag. 2009. — 746 p.
# - C. M. Bishop. Pattern Recognition and Machine Learning. — Springer, Series: Information Science and Statistics. 2006. — 738 p.
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2018_fall <номер_группы> <фамилия>``, к примеру -- ``ML2018_fall 596 ivanov``
# - Выполненное дз сохраните в файл ``ML2018_<фамилия>_<группа>_task<номер задания>.ipnb``, к примеру -- ``ML2018_ivanov_596_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2018_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Используются автоматические фильтры, и просто не найдем ваше дз, если вы неаккуратно его подпишите.
# - **PS2**: Просроченный дедлайн снижает максимальный вес задания по формуле, указнной на первом семинаре
# - **PS3**: Допустимы исправление кода предложенного кода ниже, если вы считаете

# %% [markdown]
# <h1 align="center"> Вопросы для самоконтроля </h1>
#
# Ниже приводится список вопросов, с ответами на которые может быть полезно разобраться для комфортного выполнения задания.
#
# * Основные понятия
#     1. Что такое задачи классификации, кластеризации и регрессии? Какие из них относятся к supervised learning, а какие - к unsupervised learning?
#     2. Что такое переобучение и недообучение? Как их можно детектировать?
#     3. Что такое обучающая и тестовая выборки, кросс-валидация? Как устроена k-fold cross validation?
#     4. Разложение ошибки метода обучения на bias и Variance: как ведут себя обе величины, когда увеличивается сложность семейства настраиваемых алгоритмов?
#
#
# * Простые методы
#     1. Как работает kNN в задаче классификации?
#     2. Как работает kNN с весами объектов в задаче классификации и в задаче регрессии?
#     3. Как работает наивный байесовский классификатор, в чем заключается его "наивность"?
#     4. Как приближается исходная зависимость y от x в линейной регрессии и как настраиваются веса в ней?
#     5. В чем суть проклятия размерности?
#
#
# * Измерение ошибки/точности в задачах классификации и регрессии
#     1. Как вычисляются и в каких задачах (классификации/регрессии) применяются метрики:
#     accuracy, precision, recall, F1-measure, ROC-AUC, PR-AUC, MSE, MAE, RMSE?
#     2. Решается задача бинарной классификации (с двумя классами - 0 и 1), в которой при-
#     меры из класса 0 составляют 95% выборки. Какие метрики из перечисленных в преды-
#     дущем вопросе предпочтительней использовать?
#     3. К оценке какой величины для распределения y при условии x приводят MSE и MAE?
#     4. Какая из метрик должня использоваться в задаче регрессии, чтобы ответ был равен медиане распределения прогнозируемой случайно величины?
#
#
# * Python, numpy, scipy, matplotlib, sklearn, pandas
#     1. Типы данных list, tuple, dict, set, str, unicode, hashable и unhashable.
#     2. Зачем нужны numpy и scipy? Какой тип данных в numpy используется для работы с
#     многомерными массивами? Отличия в индексации двумерного ndarray и списка списков.
#     3. Как в scipy решить численно несложную оптимизационную задачу? Какие методы оп-
#     тимизации в нем представлены?
#     4. Как по списку значений x и списку значений y в этих точках построить график y(x) в
#     matplotlib?
#     5. Как в sklearn обучить модель на обучающей выборке и получить прогнозы на тестовой?
#     6. Какие есть средства для измерения качества модели в sklearn? Как посчтитать качество
#     в k-fold cross validation?
#     7. Какие метрики можно использовать в cross_val_score из sklearn?
#     8. Как считать выборку из csv в pandas DataFrame? А как записать DataFrame в файл? Как
#     указывать при чтении/записи кодировку, используемые разделители, наличие/отсутствие
#     заголовков у колонок?

# %% [markdown]
# <h1 align="center">Теоретические вопросы (2 балла) </h1>

# %% [markdown]
# ** Задача 1**
# Покажите, что ROC-AUC  в случае, когда классификатор даёт случайные ответы $a(x) = 1$ с вероятностью $p$ и $a(x) = 0$ с вероятностью $1 − p$, будет в среднем равен 0.5 независимо от p и доли класса 1 в обучающей выборке.
#
# $\bf{Решение:}$
# Заметим, что ROC-AUC - это площадь под ROC-кривой, которая построена в координатах TPR и FPR.
# $$TPR = \frac{\sum_1^n {I\lbrace y = 1; \tilde y = 1\rbrace}}{\# \lbrace y = 1 \rbrace}$$
# $$FPR = \frac{\sum_1^n {I\lbrace y = 0; \tilde y = 1\rbrace}}{\# \lbrace y = 0 \rbrace}$$
# Найдем математическое ожидание TPR и FPR: $$E\big(TPR\big) = \frac{p * \# \lbrace y = 1 \rbrace}{\# \lbrace y = 1 \rbrace} = p$$
# $$E\big(FPR\big) = \frac{p * \# \lbrace y = 0 \rbrace}{\# \lbrace y = 0 \rbrace} = p$$
# Это так, потому что нас классификатор в обоих случаях выдает 1 с вероятностью $p$. Таким образом, мы получаем, что в среднем наша ROC-кривая - это прямая, идущая под углом $45^{\circ}$, потому что $\frac{TPR}{FPR} = 1$. А значит, площадь под ROC-кривой будет в среднем равно 50% от площади единичного квадрата, то есть 0.5.

# %% [markdown]
# ** Задача 2**
# Покажите, что с ростом размерности пространства признаков при равномерном распределении точек в кубе $[0; 1]^𝑑$ вероятность попасть в куб $[0; 0, 99]^𝑑$ стремится к нулю. Это одна из иллюстраций проклятия размерностей (dimension curse). Попробуйте придумать или найти еще какую-нибудь иллюстрацию к этому явлению и кратко изложить.
#
# $\bf{Решение}$: Заметим, что вероятность того, что наша случайно выбранная точка с равномерным распределением попала в куб со стороной $0,99$, равна $0,99^d = (1 - \frac{1}{100})^d$. Заметим, что при $d = 100 * k, k \in \mathbb{Z}$ мы получаем $0.99^d = (1 - \frac{k}{k * 100}) ^ {100 * k}$. Мы знаем, что $$\lim_{n \to \infty} (1 - \frac{t}{n}) ^ {n} = e^{-t}$$. Значит, мы получаем, что при $$\lim_{d \to \infty} 0,99^d \to e^{-\infty} = 0$$. Отсюда вероятность того, что случайная точка попадает в куб $[0; 0,99]^d$ стремится к нулю. Аналогичный пример можно привести для шара в пространстве размерности d, где мы рассматриваем шар радиуса 1 и шар радиуса $1 - \epsilon$, где $\epsilon$ - фиксированный.

# %% [markdown]
# <h1 align="center">Исследуйте зависимость Bias-Variance для kNN (3 балла) </h1>

# %% [markdown]
# Используя данные из задачи классификации доходов индивидуума http://archive.ics.uci.edu/ml/machine-learning-databases/adult, постройте зависимость величин bias, variance и noise для следующих пар "модель|параметр".
# Предобработка данных (преобразование признаков, разметка классов) определяется вами.
#
# * kNN, $n\_neigbours$ - число соседей при классификации;
# * $p$ - степень метрики Минковского;
# * $\ell\_train$ - длина обучающий выборки;
#
#
# По каждому построенному графику (для каждого параметра должен быть отдельный график) объясните полученную картину. Совпадает ли она с теоретическими ожиданиями (см. семинар 2)?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# %matplotlib inline

# Settings
n_repeat = 100       # Number of iterations for computing expectations
test_size = 0.5       # (Relative) Size of the test set

# Исследуемая сетка параметров
# пояснение: длина train выборки должна варьироваться от 50% до 200% относительно длины тестовой выборки  
parameters = {"k": np.arange(1, 20), "p":  np.arange(1, 10, 0.5), "l_train": np.arange(0.5, 2, 0.1)}

# Get Data
data = pd.read_csv('adult.csv', names=[
        "Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"], index_col=None)

data.drop(axis=1, labels=['Workclass', 'Martial Status', 'Occupation', 'Relationship', 'Race'], inplace=True)

def number_encode_features(init_df):
    result = init_df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column])
    return result

data = number_encode_features(data)

train, test = train_test_split(data, test_size=test_size)

# Для того чтобы оценить bias и variance, нужно сгенерировать случайные подвыборки с возвращением из исходного массива данных 
# (бутстрепинг)
X_train = []
y_train = []
X_test = test.iloc[:, :-1].values
y_test = test.iloc[:, -1:].values

for i in range(n_repeat):
    sample_train = train.sample(len(train), replace=True) 
    X, y = sample_train.iloc[:, :-1], sample_train.iloc[:, -1]
    X_train.append(X)
    y_train.append(y)

# %% [markdown]
# ## Зависимость от степени метрики Минковского(p)

# %%
# Для каждого значения парамера оцените значение error, bias и variance согласно следующей схеме
p_name ='p'
bias_variance_df = pd.DataFrame.from_dict({p_name:parameters[p_name],'bias':list([np.NaN]*len(parameters[p_name]))
                                           , 'variance':list([np.NaN]*len(parameters[p_name]))
                                           , 'error':list([np.NaN]*len(parameters[p_name]))})
for parameter in tqdm(parameters[p_name]):
    # Compute predictions
    y_predict = np.zeros((len(test), n_repeat))

    for i in tqdm(range(n_repeat), leave=False):
        estimator = KNeighborsClassifier(p=parameter, n_neighbors=10, n_jobs=-2).fit(X_train[i].values, y_train[i].values.ravel())
        y_predict[:, i] = estimator.predict(X_test)

    # Bias^2 + Variance + Noise decomposition of the mean squared error
    y_error = np.zeros(len(test))
    
    y_error = np.sum((y_test.repeat(n_repeat, axis=1) - y_predict) ** 2, axis=1) / n_repeat

    # В каждой точке тестовой выборки bias положим равным квадрату разности реального значения 
    # и среднего предсказанного значения по всем обучающим выборкам.
    y_bias = (y_test.ravel() - np.mean(y_predict, axis=1).ravel()) ** 2
    
    # Variance положим равным среднеквадратичному разбросу значений по всем обучающим выборкам. 
    # Итоговое значение bias и variance возьмём равным среднему по всем точкам тестовой выборки
    y_var = np.var(y_predict, axis=1)
    
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'bias'] = y_bias.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'variance'] = y_var.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'error'] = y_error.mean()
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
#
#   0%|          | 0/100 [00:00<?, ?it/s]
#
#   1%|          | 1/100 [00:00<00:16,  6.12it/s]
#
#   2%|▏         | 2/100 [00:00<00:16,  6.04it/s]
#
#   3%|▎         | 3/100 [00:00<00:15,  6.20it/s]
#
#   4%|▍         | 4/100 [00:00<00:15,  6.20it/s]
#
#   5%|▌         | 5/100 [00:00<00:15,  5.97it/s]
#
#   6%|▌         | 6/100 [00:01<00:16,  5.70it/s]
#
#   7%|▋         | 7/100 [00:01<00:16,  5.65it/s]
#
#   8%|▊         | 8/100 [00:01<00:16,  5.44it/s]
#
#   9%|▉         | 9/100 [00:01<00:16,  5.52it/s]
#
#  10%|█         | 10/100 [00:01<00:16,  5.59it/s]
#
#  11%|█         | 11/100 [00:01<00:15,  5.63it/s]
#
#  12%|█▏        | 12/100 [00:02<00:16,  5.48it/s]
#
#  13%|█▎        | 13/100 [00:02<00:16,  5.35it/s]
#
#  14%|█▍        | 14/100 [00:02<00:15,  5.42it/s]
#
#  15%|█▌        | 15/100 [00:02<00:15,  5.47it/s]
#
#  16%|█▌        | 16/100 [00:02<00:15,  5.51it/s]
#
#  17%|█▋        | 17/100 [00:03<00:15,  5.52it/s]
#
#  18%|█▊        | 18/100 [00:03<00:15,  5.46it/s]
#
#  19%|█▉        | 19/100 [00:03<00:14,  5.49it/s]
#
#  20%|██        | 20/100 [00:03<00:14,  5.52it/s]
#
#  21%|██        | 21/100 [00:03<00:14,  5.56it/s]
#
#  22%|██▏       | 22/100 [00:03<00:13,  5.59it/s]
#
#  23%|██▎       | 23/100 [00:04<00:13,  5.63it/s]
#
#  24%|██▍       | 24/100 [00:04<00:13,  5.65it/s]
#  25%|██▌       | 25/100 [00:04<00:13,  5.68it/s]Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/home/daniil/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/daniil/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/daniil/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
#
#  26%|██▌       | 26/100 [00:04<00:12,  5.70it/s]
#  27%|██▋       | 27/100 [00:04<00:12,  5.72it/s]
#  28%|██▊       | 28/100 [00:04<00:12,  5.75it/s]
#  29%|██▉       | 29/100 [00:05<00:12,  5.77it/s]
#  30%|███       | 30/100 [00:05<00:12,  5.78it/s]
#  31%|███       | 31/100 [00:05<00:11,  5.76it/s]
#  32%|███▏      | 32/100 [00:05<00:11,  5.78it/s]
#  33%|███▎      | 33/100 [00:05<00:11,  5.79it/s]
#  34%|███▍      | 34/100 [00:05<00:11,  5.81it/s]
#  35%|███▌      | 35/100 [00:06<00:11,  5.83it/s]
#  36%|███▌      | 36/100 [00:06<00:10,  5.84it/s]
#  37%|███▋      | 37/100 [00:06<00:10,  5.85it/s]
#  38%|███▊      | 38/100 [00:06<00:10,  5.86it/s]
#  39%|███▉      | 39/100 [00:06<00:10,  5.87it/s]
#  40%|████      | 40/100 [00:06<00:10,  5.88it/s]
#  41%|████      | 41/100 [00:06<00:10,  5.88it/s]
#  42%|████▏     | 42/100 [00:07<00:09,  5.90it/s]
#  43%|████▎     | 43/100 [00:07<00:09,  5.90it/s]
#  44%|████▍     | 44/100 [00:07<00:09,  5.92it/s]
#  45%|████▌     | 45/100 [00:07<00:09,  5.92it/s]
#  46%|████▌     | 46/100 [00:07<00:09,  5.88it/s]
#  47%|████▋     | 47/100 [00:07<00:08,  5.89it/s]
#  48%|████▊     | 48/100 [00:08<00:08,  5.90it/s]
#  49%|████▉     | 49/100 [00:08<00:08,
/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-04834e24852f> in <module>()
#      30
#      31 # нарисуйте зависимость bias, variance и error от значений параметров
# ---> 32 bias_variance_df.plot.line('p', ['Bias', 'Error', 'Variance'], figsize=(10, 8))
#      33 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwds)
#    2645         axes : matplotlib.AxesSubplot or np.array of them
#    2646         """
# -> 2647         return self(kind='line', x=x, y=y, **kwds)
#    2648
#    2649     def bar(self, x=None, y=None, **kwds):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1678                     y = data.columns[y]
#    1679                 label = kwds['label'] if 'label' in kwds else y
# -> 1680                 series = data[y].copy()  # Don't modify
#    1681                 series.name = label
#    1682
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Bias' 'Error' 'Variance'] not in index"

# %%
# нарисуйте зависимость bias, variance и error от значений параметров
bias_variance_df.plot.line('p', ['bias', 'error', 'variance'], figsize=(10, 8))
plt.show()

# %%
bias_variance_df.plot.line('p', 'bias')
plt.show()

# %%
bias_variance_df.plot.line('p', 'error')
plt.show()

# %%
bias_variance_df.plot.line('p', 'variance')
plt.show()

# %% [markdown]
# ## Зависимость от числа соседей(k)

# %%
# Для каждого значения парамера оцените значение error, bias и variance согласно следующей схеме
p_name ='k'
bias_variance_df = pd.DataFrame.from_dict({p_name:parameters[p_name],'bias':list([np.NaN]*len(parameters[p_name]))
                                           , 'variance':list([np.NaN]*len(parameters[p_name]))
                                           , 'error':list([np.NaN]*len(parameters[p_name]))})
for parameter in tqdm(parameters[p_name]):
    # Compute predictions
    y_predict = np.zeros((len(test), n_repeat))

    for i in tqdm(range(n_repeat), leave=False):
        estimator = KNeighborsClassifier(n_neighbors=parameter, n_jobs=-2).fit(X_train[i].values, y_train[i].values.ravel())
        y_predict[:, i] = estimator.predict(X_test)

    # Bias^2 + Variance + Noise decomposition of the mean squared error
    y_error = np.zeros(len(test))
    
    y_error = np.sum((y_test.repeat(n_repeat, axis=1) - y_predict) ** 2, axis=1) / n_repeat

    # В каждой точке тестовой выборки bias положим равным квадрату разности реального значения 
    # и среднего предсказанного значения по всем обучающим выборкам.
    y_bias = (y_test.ravel() - np.mean(y_predict, axis=1).ravel()) ** 2
    
    # Variance положим равным среднеквадратичному разбросу значений по всем обучающим выборкам. 
    # Итоговое значение bias и variance возьмём равным среднему по всем точкам тестовой выборки
    y_var = np.var(y_predict, axis=1)
    
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'bias'] = y_bias.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'variance'] = y_var.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'error'] = y_error.mean()
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|          | 1/100 [00:00<00:17,  5.76it/s]
#   2%|▏         | 2/100 [00:00<00:17,  5.74it/s]
#   3%|▎         | 3/100 [00:00<00:18,  5.36it/s]
#   4%|▍         | 4/100 [00:00<00:17,  5.46it/s]
#   5%|▌         | 5/100 [00:00<00:17,  5.34it/s]
#   6%|▌         | 6/100 [00:01<00:18,  5.15it/s]
#   7%|▋         | 7/100 [00:01<00:18,  5.06it/s]
#   8%|▊         | 8/100 [00:01<00:18,  4.99it/s]
#   9%|▉         | 9/100 [00:01<00:17,  5.13it/s]
#  10%|█         | 10/100 [00:01<00:17,  5.24it/s]
#  11%|█         | 11/100 [00:02<00:16,  5.33it/s]
#  12%|█▏        | 12/100 [00:02<00:16,  5.41it/s]
#  13%|█▎        | 13/100 [00:02<00:15,  5
/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.26it/s]
# 100%|██████████| 19/19 [05:11<00:00, 16.42s/it]

# %%
# нарисуйте зависимость bias, variance и error от значений параметров
bias_variance_df.plot.line('k', ['bias', 'error', 'variance'], figsize=(10, 8))
plt.show()

# %%
bias_variance_df.plot.line('k', 'bias')
plt.show()

# %%
bias_variance_df.plot.line('k', 'error')
plt.show()

# %%
bias_variance_df.plot.line('k', 'variance')
plt.show()

# %% [markdown]
# ## Зависимость от длины выборки(train_size)

# %%
p_name ='l_train'
bias_variance_df = pd.DataFrame.from_dict({p_name:parameters[p_name],'bias':list([np.NaN]*len(parameters[p_name]))
                                           , 'variance':list([np.NaN]*len(parameters[p_name]))
                                           , 'error':list([np.NaN]*len(parameters[p_name]))})
for parameter in tqdm(parameters[p_name]):
    # Compute predictions
    train, test = train_test_split(data, test_size=1 / (1 + parameter))
    X_train = []
    y_train = []
    for i in tqdm(range(n_repeat), leave=False):
        sample_train = train.sample(len(train), replace=True) 
        X, y = sample_train.iloc[:, :-1], sample_train.iloc[:, -1:]
        X_train.append(X)
        y_train.append(y)

    X_test, y_test = test.iloc[:, :-1].values, test.iloc[:, -1:].values
    
    y_predict = np.zeros((len(test), n_repeat))
    
    for i in range(n_repeat):
        estimator = KNeighborsClassifier(n_neighbors=10, n_jobs=-1).fit(X_train[i].values,
                                                                                     y_train[i].values.ravel())
        y_predict[:, i] = estimator.predict(X_test)

    # Bias^2 + Variance + Noise decomposition of the mean squared error
    y_error = np.zeros(len(test))

    y_error = np.sum((y_test.repeat(n_repeat, axis=1) - y_predict)**2, axis=1) / n_repeat

    # В каждой точке тестовой выборки bias положим равным квадрату разности реального значения 
    # и среднего предсказанного значения по всем обучающим выборкам.
    y_bias = (y_test.ravel() - np.mean(y_predict, axis=1).ravel()) ** 2
    
    # Variance положим равным среднеквадратичному разбросу значений по всем обучающим выборкам. 
    # Итоговое значение bias и variance возьмём равным среднему по всем точкам тестовой выборки
    y_var = np.var(y_predict, axis=1)
    
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'bias'] = y_bias.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'variance'] = y_var.mean()
    bias_variance_df.loc[bias_variance_df[p_name]==parameter, 'error'] = y_error.mean()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   7%|▋         | 1/15 [00:14<03:26, 14.76s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  13%|█▎        | 2/15 [00:35<03:53, 17.93s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  20%|██        | 3/15 [00:52<03:28, 17.34s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  27%|██▋       | 4/15 [01:07<03:06, 16.99s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  33%|███▎      | 5/15 [01:24<02:48, 16.87s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  40%|████      | 6/15 [01:40<02:31, 16.79s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  93%|█████████▎| 93/100 [00:00<00:00, 920.07it/s]
#  47%|████▋     | 7/15 [01:57<02:14, 16.79s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  95%|█████████▌| 95/100 [00:00<00:00, 940.32it/s]
#  53%|█████▎    | 8/15 [02:14<01:57, 16.84s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  83%|████████▎ | 83/100 [00:00<00:00, 825.60it/s]
#  60%|██████    | 9/15 [02:32<01:41, 16.90s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  83%|████████▎ | 83/100 [00:00<00:00, 819.75it/s]
#  67%|██████▋   | 10/15 [02:49<01:24, 16.97s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  89%|████████▉ | 89/100 [00:00<00:00, 884.70it/s]
#  73%|███████▎  | 11/15 [03:08<01:08, 17.14s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  88%|████████▊ | 88/100 [00:00<00:00, 872.23it/s]
#  80%|████████  | 12/15 [03:27<00:51, 17.27s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  91%|█████████ | 91/100 [00:00<00:00, 901.09it/s]
#  87%|████████▋ | 13/15 [03:47<00:35, 17.54s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  88%|████████▊ | 88/100 [00:00<00:00, 875.29it/s]
#  93%|█████████▎| 14/15 [04:07<00:17, 17.67s/it]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  89%|████████▉ | 89/100 [00:00<00:00, 878.56it/s]
# 100%|██████████| 15/15 [04:26<00:00, 17.79s/it]

# %%
bias_variance_df.plot.line('l_train', ['bias', 'error', 'variance'], figsize=(10, 10))
plt.show()

# %%
bias_variance_df.plot.line('l_train', 'bias')
plt.show()

# %%
bias_variance_df.plot.line('l_train', 'error')
plt.show()

# %%
bias_variance_df.plot.line('l_train', 'variance')
plt.show()

# %% [markdown]
# <h2 align="center">Реализуйте kNN (2 балла)</h2>

# %%
import warnings
import numpy as np
from collections import Counter
from scipy.spatial.distance import cdist
import tqdm

warnings.simplefilter("ignore")

def comp_sort(a, b):
    if a[0] < b[0]:
        return True
    return False

class kNNClassifier():
    def __init__(self, n_neighbours, metric):
        """
        Parameters
        ----------
        n_neighbours: int
            Число соседей

        metric: *alias
            метрика измерения расстояний

          """
        self.n_neighbours = n_neighbours
        self.metric = metric
        
    def fit(self, X, y):
        """
        
        Parameters
        ----------
        X: 2d np.array
        y: 1d np.array
        """

        # Тут храните описание объектов обучающей выборки
        self.X_learn = X
        
        # Тут храните ответы по каждому объекту обучающей выборки
        self.y_learn = y
        
        return self

    def predict(self, X):
        """
        Parameters
        ----------
        X: 2d np.array матрица объекты признаки на которых нужно сказать ответ

        Returns
        -------
        y_pred: 1d np.array, вектор классов для каждого объекта
        """
        
        dist = [] # Храните тут расстояния до каждого элемента обучающей выборки 
        dist = cdist(X, self.X_learn, self.metric)
        dist = dist.argsort()[:, :self.n_neighbours]
        y_pred = np.around(np.mean(self.y_learn[dist], axis=1))
        
        return y_pred

# %%
from scipy.spatial.distance import euclidean
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:4000, :-1], data.iloc[:4000, -1], test_size=0.2)
X_train, X_test = X_train.values, X_test.values
y_train, y_test = y_train.values.ravel(), y_test.values.ravel()
for k in [3, 5, 10]:
    clf = kNNClassifier(n_neighbours=k, metric=euclidean).fit(X_train, y_train)
    print('Accuracy score for {} train is '.format(k), accuracy_score(clf.predict(X_train), y_train))
    predict = clf.predict(X_test)
    print('Accuracy score for {} test is '.format(k), accuracy_score(predict, y_test))
# Out:
# Accuracy score for 3 train is  0.8434375
# Accuracy score for 3 test is  0.74125
# Accuracy score for 5 train is  0.8121875
# Accuracy score for 5 test is  0.77125
# Accuracy score for 10 train is  0.78375
# Accuracy score for 10 test is  0.785

# %% [markdown]
# <h1 align="center">Отбор признаков (3 балла) </h1>

# %% [markdown]
# Реализуйте алгоритм отбора признаков ADD_DELL и примените его для kNN на данных sklearn.datasets.digits().
# Для этого предлагается реализовать следующие функции

# %%
# обновление минимального значения ошибки
def update_Q_min_index(estimator, Q_min, Q_min_set, Q_min_index, feature_set, X_train, Y_train, X_test, Y_test, update_equal=False):
    feature_set_size = len(feature_set)
    estimator.fit(X_train[:, feature_set], Y_train)
    error = 1 - accuracy_score(Y_test, estimator.predict(X_test[:, feature_set]))
    if error < Q_min[feature_set_size]:
        Q_min_set[feature_set_size] = feature_set
        Q_min[feature_set_size] = error
        if ((Q_min[feature_set_size] < Q_min[Q_min_index])
                or (update_equal and Q_min[feature_set_size] == Q_min[Q_min_index])):
            Q_min_index = feature_set_size
    return Q_min_index


# Нужно реализовать алгоритм добавление
def add_one(estimator, feature_set, X_train, Y_train, X_test, Y_test, look_forward=10, start_feature_set=[]):
    Q_min = {0: float('+inf')}
    Q_min_set = {0: []}
    Q_min_index = 0
    
    # инициализация стартового набора признаков     
    if start_feature_set:
        estimator.fit(X_train[:, start_feature_set], Y_train)
        error = 1 - accuracy_score(Y_test, estimator.predict(X_test[:, start_feature_set]))
        Q_min = {len(start_feature_set) : error}
        Q_min_set = {len(start_feature_set) : start_feature_set}
        Q_min_index = len(start_feature_set)
    
    # добавление признаков     
    for feature_set_size in range(len(start_feature_set) + 1, len(feature_set) + 1):
        Q_min[feature_set_size] = float('+inf')
        unused_features = set(feature_set).difference(set(Q_min_set[feature_set_size - 1]))
        unused_features = list(unused_features)
        #shuffle(unused_features)
        for feature in unused_features:
            new_feature_set = Q_min_set[feature_set_size - 1] + [feature]
            Q_min_index = update_Q_min_index(estimator, Q_min, Q_min_set, Q_min_index, new_feature_set,
                                            X_train, Y_train, X_test, Y_test)
        
        
        print ('Q_min: %.4lf, set_size: %d, added: %s' % (Q_min[feature_set_size], feature_set_size, Q_min_set[feature_set_size][-1]))        
    
    # критерий останова
        if Q_min_index + look_forward <= feature_set_size:
            break
    return Q_min_set[feature_set_size]

def del_one(estimator, feature_set, X_train, Y_train, X_test, Y_test, look_forward=10):
    
#     инициализация
    estimator.fit(X_train[:, feature_set], Y_train)
    error = 1 - accuracy_score(Y_test, estimator.predict(X_test[:, feature_set]))
    Q_min = {len(feature_set): error}
    Q_min_set = {len(feature_set): feature_set}
    Q_min_index = len(feature_set)
    
#     итерационное удаление признаков
    for feature_set_size in list(range(len(feature_set) - 1, 0, -1)):
        Q_min[feature_set_size] = float('+inf')
        features = Q_min_set[feature_set_size + 1]
        # shuffle(features)
        for feature in features:
            new_feature_set = list(set(features).difference({feature}))
            Q_min_index = update_Q_min_index(estimator, Q_min, Q_min_set, Q_min_index, new_feature_set,
                                            X_train, Y_train, X_test, Y_test)
            
        print ('Q_min: %.4lf, set_size: %d, deleted: %s' % (Q_min[feature_set_size], feature_set_size,
            set(Q_min_set[feature_set_size + 1]).difference(set(Q_min_set[feature_set_size])),
        ))
        
#         критерий останова
        if feature_set_size + look_forward <= Q_min_index:
            break
    return Q_min_set[Q_min_index]

# Наконец, реализуйте ADD-DELL
def add_del(estimator, feature_set, X_train, Y_train, X_test, Y_test, look_forward=10):
    Q_min = None
    Q_min_current = float('+inf')
    start_feature_set = []
    
#     количество итераций, приведших к увеличению ошибки
    bad_iteration_count = 2
    best_feat_set = []
    while (Q_min is None) or (Q_min_current < Q_min or bad_iteration_count):
        Q_min = Q_min_current
        start_feature_set = add_one(estimator, feature_set, X_train, Y_train, X_test, Y_test, look_forward, start_feature_set=start_feature_set)
        start_feature_set = del_one(estimator, start_feature_set, X_train, Y_train, X_test, Y_test, look_forward)
        estimator.fit(X_train[:, start_feature_set], Y_train)
        Q_min_current = 1 - accuracy_score(Y_test, estimator.predict(X_test[:, start_feature_set]))
        
        if Q_min_current >= Q_min:
            bad_iteration_count -= 1
        else:
            best_feat_set = start_feature_set.copy()
        print ('Q_min: %.4lf, set_size: %d' % (Q_min_current, len(start_feature_set)))
    return best_feat_set

# %%
from sklearn.datasets import load_digits

data, labels = load_digits(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(data, labels)
# проверьте вашу реализацию
estimator = KNeighborsClassifier()
# %time feature_set = add_del(estimator, list(range(X_train.shape[1])), X_train, Y_train, X_test, Y_test, look_forward=4)
# %time accuracy_score(Y_test, estimator.fit(X_train[:, feature_set], Y_train).predict(X_test[:, feature_set]))
# Out:
# Q_min: 0.7400, set_size: 1, added: 28
# Q_min: 0.6067, set_size: 2, added: 44
# Q_min: 0.4511, set_size: 3, added: 36
# Q_min: 0.3578, set_size: 4, added: 35
# Q_min: 0.2644, set_size: 5, added: 21
# Q_min: 0.1867, set_size: 6, added: 59
# Q_min: 0.1578, set_size: 7, added: 20
# Q_min: 0.1200, set_size: 8, added: 60
# Q_min: 0.1044, set_size: 9, added: 5
# Q_min: 0.0844, set_size: 10, added: 27
# Q_min: 0.0622, set_size: 11, added: 37
# Q_min: 0.0511, set_size: 12, added: 33
# Q_min: 0.0467, set_size: 13, added: 19
# Q_min: 0.0378, set_size: 14, added: 18
# Q_min: 0.0311, set_size: 15, added: 43
# Q_min: 0.0244, set_size: 16, added: 50
# Q_min: 0.0222, set_size: 17, added: 6
# Q_min: 0.0200, set_size: 18, added: 41
# Q_min: 0.0156, set_size: 19, added: 53
# Q_min: 0.0133, set_size: 20, added: 13
# Q_min: 0.0111, set_size: 21, added: 34
# Q_min: 0.0111, set_size: 22, added: 0
# Q_min: 0.0111, set_size: 23, added: 1
# Q_min: 0.0111, set_size: 24, added: 3
# Q_min: 0.0111, set_size: 25, added: 7
# Q_min: 0.0111, set_size: 24, deleted: {35}
# Q_min: 0.0111, set_size: 23, deleted: {0}
# Q_min: 0.0111, set_size: 22, deleted: {1}
# Q_min: 0.0111, set_size: 21, deleted: {6}
# Q_min: 0.0111, set_size: 25
# Q_min: 0.0111, set_size: 26, added: 8
# Q_min: 0.0111, set_size: 27, added: 12
# Q_min: 0.0089, set_size: 28, added: 9
# Q_min: 0.0089, set_size: 29, added: 15
# Q_min: 0.0089, set_size: 30, added: 16
# Q_min: 0.0089, set_size: 31, added: 23
# Q_min: 0.0089, set_size: 32, added: 24
# Q_min: 0.0089, set_size: 31, deleted: {0}
# Q_min: 0.0089, set_size: 30, deleted: {1}
# Q_min: 0.0089, set_size: 29, deleted: {7}
# Q_min: 0.0089, set_size: 28, deleted: {8}
# Q_min: 0.0089, set_size: 32
# Q_min: 0.0089, set_size: 33, added: 25
# Q_min: 0.0089, set_size: 34, added: 31
# Q_min: 0.0089, set_size: 35, added: 32
# Q_min: 0.0089, set_size: 36, added: 39
# Q_min: 0.0089, set_size: 35, deleted: {44}
# Q_min: 0.0089, set_size: 34, deleted: {0}
# Q_min: 0.0089, set_size: 33, deleted: {1}
# Q_min: 0.0089, set_size: 32, deleted: {7}
# Q_min: 0.0089, set_size: 36
# Q_min: 0.0089, set_size: 37, added: 40
# Q_min: 0.0089, set_size: 38, added: 45
# Q_min: 0.0089, set_size: 39, added: 47
# Q_min: 0.0089, set_size: 40, added: 48
# Q_min: 0.0089, set_size: 39, deleted: {0}
# Q_min: 0.0089, set_size: 38, deleted: {1}
# Q_min: 0.0089, set_size: 37, deleted: {7}
# Q_min: 0.0089, set_size: 36, deleted: {8}
# Q_min: 0.0089, set_size: 40
# CPU times: user 38.2 s, sys: 35.9 ms, total: 38.2 s
# Wall time: 38.2 s
# CPU times: user 28.2 ms, sys: 0 ns, total: 28.2 ms
# Wall time: 28.2 ms
# 0.99111111111111116
